# %% [markdown]
# <a href="https://colab.research.google.com/github/raaedkhaan/Ai-lab-tasks/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB TASK 1

# %%
from collections import deque

# Weighted Graph
graph = {
    'A': [('B',2), ('C',4)],
    'B': [('D',3)],
    'C': [('D',5)],
    'D': [('G',1)],
    'G': []
}

def bfs_cost(graph, start, goal):

    queue = deque()
    queue.append((start, [start], 0))   # node, path, cost

    visited = []

    while queue:

        node, path, cost = queue.popleft()

        if node == goal:
            return path, cost

        if node not in visited:
            visited.append(node)

            for neighbour, weight in graph[node]:
                queue.append(
                    (neighbour,
                     path + [neighbour],
                     cost + weight)
                )

    return None


# Driver Code
path, total_cost = bfs_cost(graph,'A','G')

print("Path:", path)
print("Total Cost:", total_cost)
# Out:
# Path: ['A', 'B', 'D', 'G']
# Total Cost: 6

# %% [markdown]
# # LAB TASK 2

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create Graph
G = nx.Graph()

# Add edges with distances
edges = [
    ('Arad','Sibiu',140),
    ('Arad','Timisoara',118),
    ('Sibiu','Fagaras',99),
    ('Fagaras','Bucharest',211),
    ('Timisoara','Lugoj',111),
    ('Lugoj','Mehadia',70),
    ('Mehadia','Drobeta',75),
    ('Drobeta','Craiova',120),
    ('Craiova','Pitesti',138),
    ('Pitesti','Bucharest',101)
]

G.add_weighted_edges_from(edges)

# Draw Graph
pos = nx.spring_layout(G)

nx.draw(G, pos,
        with_labels=True,
        node_size=2000,
        node_color='lightblue',
        font_size=10)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title("Romania Map Graph")
plt.show()

# %%
def bfs(graph, start, goal):

    queue = deque()
    queue.append((start,[start],0))
    visited = []

    while queue:

        city, path, cost = queue.popleft()

        if city == goal:
            return path, cost

        if city not in visited:
            visited.append(city)

            for neighbour, distance in graph[city]:
                queue.append(
                    (neighbour,
                     path + [neighbour],
                     cost + distance)
                )

path, distance = bfs(graph,'Arad','Bucharest')

print("Path Found:")
print(" -> ".join(path))

print("\nTotal Distance:",distance,"km")
# Out:
# Path Found:
# Arad -> Sibiu -> Fagaras -> Bucharest
#
# Total Distance: 450 km
